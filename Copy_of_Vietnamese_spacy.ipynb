# %% [markdown]
# <a href="https://colab.research.google.com/github/TranMyLinh-297/QA_Law_VN/blob/master/Copy_of_Vietnamese_spacy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Demo

# %%
# !pip install spacy==2.2.1 pyvi https://github.com/trungtv/vi_spacy/raw/master/packages/vi_spacy_model-0.2.1/dist/vi_spacy_model-0.2.1.tar.gz
# Out:
# ...
#      |████████████████████████████████| 42.3MB 103kB/s
# ...
#      |████████████████████████████████| 10.2MB 4.9MB/s
# ...
#      |████████████████████████████████| 8.5MB 45.9MB/s
# ...
#      |████████████████████████████████| 2.1MB 39.2MB/s
# ...
#      |████████████████████████████████| 747kB 38.6MB/s
# ...
#   Created wheel for vi-spacy-model: filename=vi_spacy_model-0.2.1-cp36-none-any.whl size=42371398 sha256=d9be314bcb7fc67441e783e68d2c54181d7222a23c2d2fab7492de5c9ab2da7a
#   Stored in directory: /root/.cache/pip/wheels/b5/82/13/0f35f2507fa2fb840bb8403a4ca9171509129c48d9a8b6df15
# Successfully built vi-spacy-model
# ERROR: en-core-web-sm 2.2.5 has requirement spacy>=2.2.2, but you'll have spacy 2.2.1 which is incompatible.
# ...
#   Found existing installation: plac 1.1.3
#     Uninstalling plac-1.1.3:
#       Successfully uninstalled plac-1.1.3
#   Found existing installation: thinc 7.4.0
#     Uninstalling thinc-7.4.0:
#       Successfully uninstalled thinc-7.4.0
#   Found existing installation: spacy 2.2.4
# ...

# %%
import spacy
nlp = spacy.load('vi_spacy_model')

# %%
text = "Bộ luật Lao động quy định tiêu chuẩn lao động; quyền, nghĩa vụ, trách nhiệm của người lao động, người sử dụng lao động, tổ chức đại diện người lao động tại cơ sở, tổ chức đại diện người sử dụng lao động trong quan hệ lao động và các quan hệ khác liên quan trực tiếp đến quan hệ lao động; quản lý nhà nước về lao động."
doc = nlp(text)

# %%
import pandas as pd

# %%
tokens = []
for token in doc:
    tokens.append(
        {
         'token': token.text,
         'lemma': token.lemma_,
         'pos': token.pos_,
         'tag': token.tag_,
         'dep': token.dep_,
         'shape': token.shape_,
         'is_alpha': token.is_alpha,
         'is_stop': token.is_stop
        }
    )

df = pd.DataFrame(tokens)
df
# Out:
#           token        lemma pos tag       dep        shape  is_alpha  is_stop
# 0       Bộ_luật      Bộ_luật   X   N     nsubj      xxxxxxx     False    False
# 1      Lao_động     Lao_động   X   N  compound     xxxxxxxx     False    False
# 2      quy_định     quy_định   X   V  compound     xxxxxxxx     False    False
# 3    tiêu_chuẩn   tiêu_chuẩn   X   N  compound   xxxxxxxxxx     False    False
# 4      lao_động     lao_động   X   N  compound     xxxxxxxx     False    False
# 5             ;            ;   X   ;     punct            ;     False    False
# 6         quyền        quyền   X   N     appos        xxxxx      True    False
# 7             ,            ,   X   ,     punct            ,     False    False
# 8      nghĩa_vụ     nghĩa_vụ   X   N      conj     xxxxxxxx     False    False
# 9             ,            ,   X   ,     punct            ,     False    False
# 10  trách_nhiệm  trách_nhiệm   X   N      conj  xxxxxxxxxxx     False    False
# ...

# %%
options = {"fine_grained": True}
spacy.displacy.render(doc, style="dep", jupyter=True, options=options)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="vi" id="b065ba446cad4036a4fb7b7e27945f95-0" class="displacy" width="7225" height="924.5" direction="ltr" style="max-width: none; height: 924.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Bộ_luật</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">N</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Lao_động</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">N</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">quy_định</tspan>
# ...

# %% [markdown]
# # Luat Doanh Nghiep

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-03b244ed-3aba-472d-99e6-0204173d4d07" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-03b244ed-3aba-472d-99e6-0204173d4d07">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving luatdoanhnghiep.txt to luatdoanhnghiep.txt

# %%
with open('/content/luatdoanhnghiep.txt', encoding='utf8') as f:
    contents = f.readlines()

# %%
ten=[]
noidung=[]
for i in range(len(contents)):
    if contents[i][:5]== "Điều ":
        ten.append(contents[i].replace("\n", ""))
        try:
            noidung.append(nd)
        except:
            nd= ''        
        nd= ''
    else:
        if nd == '':
            nd =nd + ' ' + contents[i].replace("\n", "")
        else:
            nd =nd + contents[i].replace("\n", "")
noidung.append(nd)

# %%
import pandas as pd
data = pd.DataFrame()
data['ten'] = ten
data['noidung'] = noidung
data
# Out:
#                                                    ten                                            noidung
# 0                           Điều 1. Phạm vi điều chỉnh   Luật này quy định về việc thành lập, tổ chức ...
# 1                            Điều 2. Đối tượng áp dụng   1. Doanh nghiệp.2. Cơ quan, tổ chức, cá nhân ...
# 2       Điều 3. Áp dụng Luật Doanh nghiệp và luật khác   Trường hợp luật khác có quy định đặc thù về v...
# 3                            Điều 4. Giải thích từ ngữ   Trong Luật này, các từ ngữ dưới đây được hiểu...
# 4    Điều 5. Bảo đảm của Nhà nước đối với doanh ngh...   1. Nhà nước công nhận sự tồn tại lâu dài và p...
# ..                                                 ...                                                ...
# 213                     Điều 214. Phá sản doanh nghiệp   Việc phá sản doanh nghiệp được thực hiện theo...
# 214  Điều 215. Trách nhiệm các cơ quan quản lý nhà ...   1. Chính phủ thống nhất quản lý nhà nước đối ...
# ...

# %%
options = {"fine_grained": True}
spacy.displacy.render(doc, style="dep", jupyter=True, options=options)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="vi" id="8b15a036d2034de88664f28ebf272ecc-0" class="displacy" width="5825" height="924.5" direction="ltr" style="max-width: none; height: 924.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Luật</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">N</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">này</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">P</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">quy_định</tspan>
# ...

# %%
text = noidung[0]
doc = nlp(text)
tokens = []
for token in doc:
    tokens.append(
        {
         'token': token.text,
         'lemma': token.lemma_,
         'pos': token.pos_,
         'tag': token.tag_,
         'dep': token.dep_,
         'shape': token.shape_,
         'is_alpha': token.is_alpha,
         'is_stop': token.is_stop
        }
    )

df = pd.DataFrame(tokens)
df
# Out:
#            token         lemma pos  ...         shape is_alpha is_stop
# 0           Luật          Luật   X  ...          xxxx     True   False
# 1            này           này   X  ...           xxx     True    True
# 2       quy_định      quy_định   X  ...      xxxxxxxx    False   False
# 3             về            về   X  ...            xx     True    True
# 4           việc          việc   X  ...          xxxx     True    True
# 5      thành_lập     thành_lập   X  ...     xxxxxxxxx    False   False
# 6              ,             ,   X  ...             ,    False   False
# 7        tổ_chức       tổ_chức   X  ...       xxxxxxx    False   False
# 8        quản_lý       quản_lý   X  ...       xxxxxxx    False   False
# 9              ,             ,   X  ...             ,    False   False
# 10       tổ_chức       tổ_chức   X  ...       xxxxxxx    False   False
# 11           lại           lại   X  ...           xxx     True    True
# ...

# %%
entity = [["Luật", "thành_lập doanh_nghiệp"], ["Luật", "tổ_chức quản_lý doanh_nghiệp"], ["Luật","giải thể doanh nghiệp"], 
          ["Luật", "hoạt_động doanh_nghiệp"], ["doanh_nghiệp", "công_ty trách_nhiệm hữu_hạn"], ["doanh_nghiệp", "công_ty cổ_phần"],
          ["doanh_nghiệp", "công_ty cổ_phần"], ["doanh_nghiệp", "công_ty hợp_doanh"], ["doanh_nghiệp", "doanh_nghiệp tư_nhân"], ["Luật", "nhóm công_ty"]]
relation = ["quy_định", "quy_định", "quy_định", "quy_định", "bao_gồm", "bao_gồm", "bao_gồm", "bao_gồm", "bao_gồm", "quy_định"]

# %%
# extract subject
source = [i[0] for i in entity]

# extract object
target = [i[1] for i in entity]

kg_df = pd.DataFrame({'source':source, 'target':target, 'edge':relation})

# %%
import networkx as nx
G=nx.from_pandas_edgelist(kg_df, "source", "target", 
                          edge_attr=True, create_using=nx.MultiDiGraph())

# %%
noidung[0]
# Out:
# ' Luật này quy định về việc thành lập, tổ chức quản lý, tổ chức lại, giải thể và hoạt động có liên quan của doanh nghiệp, bao gồm công ty trách nhiệm hữu hạn, công ty cổ phần, công ty hợp danh và doanh nghiệp tư nhân; quy định về nhóm công ty.'

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,12))

pos = nx.spring_layout(G)
nx.draw(G, with_labels=True, node_color='skyblue', edge_cmap=plt.cm.Blues, pos = pos)
plt.show()

# %%
noidung[0]
# Out:
# ' Luật này quy định về việc thành lập, tổ chức quản lý, tổ chức lại, giải thể và hoạt động có liên quan của doanh nghiệp, bao gồm công ty trách nhiệm hữu hạn, công ty cổ phần, công ty hợp danh và doanh nghiệp tư nhân; quy định về nhóm công ty.'

# %%
type(df["tag"][0])
# Out:
# str

# %%
entity1 = ""
entity2 = ""
entity = []
relation = []
if

# %%
def get_entities(sent):
  ## chunk 1
  ent1 = ""
  ent2 = ""

  prv_tok_dep = ""    # dependency tag of previous token in the sentence
  prv_tok_text = ""   # previous token in the sentence

  prefix = ""
  modifier = ""

  #############################################################
  
  for tok in nlp(sent):
    ## chunk 2
    # if token is a punctuation mark then move on to the next token
    if tok.dep_ != "punct":
      # check: token is a compound word or not
      if tok.dep_ == "compound":
        prefix = tok.text
        # if the previous word was also a 'compound' then add the current word to it
        if prv_tok_dep == "compound":
          prefix = prv_tok_text + " "+ tok.text
      
      # check: token is a modifier or not
      if tok.dep_.endswith("mod") == True:
        modifier = tok.text
        # if the previous word was also a 'compound' then add the current word to it
        if prv_tok_dep == "compound":
          modifier = prv_tok_text + " "+ tok.text
      
      ## chunk 3
      if tok.dep_.find("subj") == True:
        ent1 = modifier +" "+ prefix + " "+ tok.text
        prefix = ""
        modifier = ""
        prv_tok_dep = ""
        prv_tok_text = ""      

      ## chunk 4
      if tok.dep_.find("obj") == True:
        ent2 = modifier +" "+ prefix +" "+ tok.text
        
      ## chunk 5  
      # update variables
      prv_tok_dep = tok.dep_
      prv_tok_text = tok.text
  #############################################################

  return [ent1.strip(), ent2.strip()]
